# %%
# Importing dependencies 
import pandas as pd
import numpy as np
import scipy.stats as st
import os

# Importing time traveled to work (county and state) csvs and concatonating into a sigle dataframe
path1 = 'Resources/Travel Time to Work'
files1 = os.listdir(path1)
travel_df = pd.DataFrame()
for file in files1:
    temp1 = pd.read_csv(path1 + '\\' + file, skiprows=[1])
    temp1 = temp1[['B08303_001E', 'B08303_002E', 'B08303_003E', 'B08303_004E', 'B08303_005E', 'B08303_006E', 'B08303_007E', \
        'B08303_008E', 'B08303_009E', 'B08303_010E', 'B08303_011E', 'B08303_012E', 'B08303_013E', 'NAME']]
    #Renaming columns 
    temp1.columns = ['Total Estimate', 'Estimate Less than 5 min', 'Estimate 5 to 9 min', 'Estimate 10 to 14 min', \
        'Estimate 15 to 19 min', 'Estimate 20 to 24 min', 'Estimate 25 to 29 min', 'Estimate 30 to 34 min', 'Estimate 35 to 39 min', \
        'Estimate 40 to 44 min', 'Estimate 45 to 59 min', 'Estimate 60 to 89 min', 'Estimate 90 or more min', 'State']
    # Adding a column for respective years
    temp1['Year'] = file.split(' ')[0]
    # reordering columns
    temp1 = temp1[['Year', 'State', 'Total Estimate', 'Estimate Less than 5 min', 'Estimate 5 to 9 min', 'Estimate 10 to 14 min', \
        'Estimate 15 to 19 min', 'Estimate 20 to 24 min', 'Estimate 25 to 29 min', 'Estimate 30 to 34 min', 'Estimate 35 to 39 min', \
        'Estimate 40 to 44 min', 'Estimate 45 to 59 min', 'Estimate 60 to 89 min', 'Estimate 90 or more min']]
    # Removing Puerto Rico
    temp1 = temp1[temp1['State'].str.contains('Puerto Rico')==False]
    # Appending each new temporary dataframe into one
    travel_df = travel_df.append(temp1)

# Importing time traveled to work (county and state) csvs and concatonating into a sigle dataframe
path2 = 'Resources/Travel Time County and State Level'
files2 = os.listdir(path2)
cs_travel_df = pd.DataFrame()
for file in files2:
    temp = pd.read_csv(path2 + '\\' + file, skiprows=[1])
    temp = temp[['B08131_001E', 'B08131_002E', 'B08131_003E', 'B08131_004E', 'B08131_005E', 'NAME']]
    # Renaming columns 
    temp.columns = ['Estimate Aggregate Travel Time (min)', 'Worked in State of Residence Estimate Aggregate (min)', \
        'Worked in County of Residence Estimate Aggregate (min)', 'Worked Outside County of Residence Estimate Aggregate (min)', \
        'Worked Outside State of Residence Estimate Aggregate (min)', 'State']
    # Adding a column for respective years
    temp['Year'] = file.split(' ')[0]
    # Reordering columns
    temp = temp[['Year', 'State', 'Estimate Aggregate Travel Time (min)', 'Worked in State of Residence Estimate Aggregate (min)', \
        'Worked in County of Residence Estimate Aggregate (min)', 'Worked Outside County of Residence Estimate Aggregate (min)', \
        'Worked Outside State of Residence Estimate Aggregate (min)']]
    # Removing Puerto Rico
    temp = temp[temp['State'].str.contains('Puerto Rico')==False]
    # Appending each new temporary dataframe into one
    cs_travel_df = cs_travel_df.append(temp)

# Importing HPI csv and making into a dataframe
hpi_quarterly = pd.read_csv('Resources/HPI/HPI Quarterly State Level.csv')
# Removing Warning column
hpi_quarterly = hpi_quarterly[['state', 'yr', 'qtr', 'index_nsa', 'index_sa']]
# Renaming columns
hpi_quarterly.columns = ['State', 'Year', 'Quarter', 'NSA Index', 'SA Index']
# Gropuby to get mean of SA and NSA index for each state and year
hpi_yearly = hpi_quarterly.groupby(['State', 'Year'], as_index=False).agg({'NSA Index': 'mean', 'SA Index': 'mean'})
# Renaming columns again 
hpi_yearly.columns = ['State', 'Year', 'Yearly Average Index (NSA)', 'Yearly Average Index (SA)']
# Only keeping years 2010-2019
hpi_yearly = hpi_yearly.loc[(hpi_yearly['Year'].astype(int) >= 2010) & (hpi_yearly['Year'].astype(int) <= 2019)]

# %%
travel_df
# Out:
#     Year          State  Total Estimate  Estimate Less than 5 min  \
# 0   2010        Alabama         1895987                     59051
# 1   2010         Alaska          324619                     30199
# 2   2010        Arizona         2470950                     66596
# 3   2010       Arkansas         1189709                     60584
# 4   2010     California        15097170                    346580
# ..   ...            ...             ...                       ...
# 46  2019       Virginia         4044679                     81541
# 47  2019     Washington         3481251                     88373
# 48  2019  West Virginia          702086                     26662
# 49  2019      Wisconsin         2808648                    118333
# 50  2019        Wyoming          263524                     20543
#
#     Estimate 5 to 9 min  Estimate 10 to 14 min  Estimate 15 to 19 min  \
# 0                189676                 274724                 330572
# 1                 56593                  58333                  59252
# 2                243712                 346279                 385741
# 3                171728                 203607                 207225
# 4               1331209                2102009                2350056
# ..                  ...                    ...                    ...
# 46               318095                 464607                 598280
# 47               307571                 405405                 505883
# 48                80149                 106219                 109586
# 49               365548                 448298                 469881
# 50                64799                  53292                  46264
#
#     Estimate 20 to 24 min  Estimate 25 to 29 min  Estimate 30 to 34 min  \
# 0                  301885                 117283                 264594
# 1                   44082                  16062                  24726
# 2                  376165                 166696                 390622
# 3                  163084                  73975                 136006
# 4                 2255417                 851250                2224075
# ..                    ...                    ...                    ...
# 46                 570837                 284185                 584991
# 47                 474369                 236353                 478642
# 48                  95673                  47189                  78676
# 49                 412629                 198922                 309935
# 50                  22214                   6119                  14962
#
#     Estimate 35 to 39 min  Estimate 40 to 44 min  Estimate 45 to 59 min  \
# 0                   53632                  56160                 135707
# 1                    5249                   4035                  12229
# 2                   71040                 104917                 179809
# 3                   30393                  28008                  60070
# 4                  385428                 590185                1188689
# ..                    ...                    ...                    ...
# 46                 141495                 171602                 389094
# 47                 117565                 166593                 329245
# 48                  17829                  21563                  49325
# 49                  85529                  94505                 161429
# 50                   3071                   4605                  10513
#
#     Estimate 60 to 89 min  Estimate 90 or more min
# 0                   76275                    36428
# 1                    8194                     5665
# 2                   99719                    39654
# 3                   35293                    19736
# 4                 1019773                   452499
# ..                    ...                      ...
# 46                 301947                   138005
# 47                 245917                   125335
# 48                  41812                    27403
# 49                  93629                    50010
# 50                   9821                     7321
#
# [510 rows x 15 columns]

# %%
us_state_to_abbrev = {"Alabama": "AL", "Alaska": "AK", "Arizona": "AZ", "Arkansas": "AR", "California": "CA", "Colorado": "CO", \
    "Connecticut": "CT", "Delaware": "DE", "Florida": "FL", "Georgia": "GA", "Hawaii": "HI", "Idaho": "ID", "Illinois": "IL", \
    "Indiana": "IN", "Iowa": "IA", "Kansas": "KS", "Kentucky": "KY", "Louisiana": "LA", "Maine": "ME", "Maryland": "MD", \
    "Massachusetts": "MA", "Michigan": "MI", "Minnesota": "MN", "Mississippi": "MS", "Missouri": "MO", "Montana": "MT", "Nebraska": "NE", \
    "Nevada": "NV", "New Hampshire": "NH", "New Jersey": "NJ", "New Mexico": "NM", "New York": "NY", "North Carolina": "NC", "North Dakota": "ND", \
    "Ohio": "OH", "Oklahoma": "OK", "Oregon": "OR", "Pennsylvania": "PA", "Rhode Island": "RI", "South Carolina": "SC", "South Dakota": "SD", \
    "Tennessee": "TN", "Texas": "TX", "Utah": "UT", "Vermont": "VT", "Virginia": "VA", "Washington": "WA", "West Virginia": "WV", \
    "Wisconsin": "WI", "Wyoming": "WY", "District of Columbia": "DC"
}

# %%
# Changing state names to abbreviations
travel_df = travel_df.replace({'State': us_state_to_abbrev})
cs_travel_df = cs_travel_df.replace({'State': us_state_to_abbrev})

# Merging HPI and travel time dataframes
travels = pd.merge(travel_df, cs_travel_df, on=['State', 'Year'], how='left')
# Changing HPI year column back into strings to maintain compatibility 
hpi_yearly['Year'] = hpi_yearly['Year'].astype(str)
travel_hpi = pd.merge(travels, hpi_yearly, on=['State', 'Year'], how='left')

# Saving merged dataframe in Resources folder
travel_hpi.to_csv('Resources/2010 to 2019 HPI and Travel Time to Work.csv')

# %%
travels
# Out:
#      Year State  Total Estimate  Estimate Less than 5 min  \
# 0    2010    AL         1895987                     59051
# 1    2010    AK          324619                     30199
# 2    2010    AZ         2470950                     66596
# 3    2010    AR         1189709                     60584
# 4    2010    CA        15097170                    346580
# ..    ...   ...             ...                       ...
# 505  2019    VA         4044679                     81541
# 506  2019    WA         3481251                     88373
# 507  2019    WV          702086                     26662
# 508  2019    WI         2808648                    118333
# 509  2019    WY          263524                     20543
#
#      Estimate 5 to 9 min  Estimate 10 to 14 min  Estimate 15 to 19 min  \
# 0                 189676                 274724                 330572
# 1                  56593                  58333                  59252
# 2                 243712                 346279                 385741
# 3                 171728                 203607                 207225
# 4                1331209                2102009                2350056
# ..                   ...                    ...                    ...
# 505               318095                 464607                 598280
# 506               307571                 405405                 505883
# 507                80149                 106219                 109586
# 508               365548                 448298                 469881
# 509                64799                  53292                  46264
#
#      Estimate 20 to 24 min  Estimate 25 to 29 min  Estimate 30 to 34 min  \
# 0                   301885                 117283                 264594
# 1                    44082                  16062                  24726
# 2                   376165                 166696                 390622
# 3                   163084                  73975                 136006
# 4                  2255417                 851250                2224075
# ..                     ...                    ...                    ...
# 505                 570837                 284185                 584991
# 506                 474369                 236353                 478642
# 507                  95673                  47189                  78676
# 508                 412629                 198922                 309935
# 509                  22214                   6119                  14962
#
#      Estimate 35 to 39 min  Estimate 40 to 44 min  Estimate 45 to 59 min  \
# 0                    53632                  56160                 135707
# 1                     5249                   4035                  12229
# 2                    71040                 104917                 179809
# 3                    30393                  28008                  60070
# 4                   385428                 590185                1188689
# ..                     ...                    ...                    ...
# 505                 141495                 171602                 389094
# 506                 117565                 166593                 329245
# 507                  17829                  21563                  49325
# 508                  85529                  94505                 161429
# 509                   3071                   4605                  10513
#
#      Estimate 60 to 89 min  Estimate 90 or more min  \
# 0                    76275                    36428
# 1                     8194                     5665
# 2                    99719                    39654
# 3                    35293                    19736
# 4                  1019773                   452499
# ..                     ...                      ...
# 505                 301947                   138005
# 506                 245917                   125335
# 507                  41812                    27403
# 508                  93629                    50010
# 509                   9821                     7321
#
#      Estiamte Aggregate Travel Time (min)  \
# 0                                45734230
# 1                                 6100595
# 2                                60533900
# 3                                25178550
# 4                               405422285
# ..                                    ...
# 505                             117533485
# 506                             100088410
# 507                              18501245
# 508                              63667210
# 509                               5037795
#
#      Worked in State of Residence Estimate Aggregate (min)  \
# 0                                             42487215
# 1                                              6069265
# 2                                             58957890
# 3                                             23519785
# 4                                            402553330
# ..                                                 ...
# 505                                          100009500
# 506                                           95647125
# 507                                           14119905
# 508                                           59039905
# 509                                            4635125
#
#      Worked in County of Residence Estimate Aggregate (min)  \
# 0                                             25986650
# 1                                              4973180
# 2                                             53765435
# 3                                             14298840
# 4                                            285220410
# ..                                                 ...
# 505                                           37119195
# 506                                           68366485
# 507                                            8387660
# 508                                           34763360
# 509                                            3821070
#
#     Worked Outside County of Residence Estimate Aggregate (min)  \
# 0                                             16500565
# 1                                              1096085
# 2                                              5192455
# 3                                              9220950
# 4                                            117332920
# ..                                                 ...
# 505                                           62890300
# 506                                           27280640
# 507                                            5732245
# 508                                           24276545
# 509                                             814055
#
#      Worked Outside State of Residence Estimate Aggregate (min)
# 0                                              3247015
# 1                                                31325
# 2                                              1576015
# 3                                              1658765
# 4                                              2868955
# ..                                                 ...
# 505                                           17523985
# 506                                            4441285
# 507                                            4381340
# 508                                            4627305
# 509                                             402670
#
# [510 rows x 20 columns]

# %%
travel_hpi
# Out:
#      Year State  Total Estimate  Estimate Less than 5 min  \
# 0    2010    AL         1895987                     59051
# 1    2010    AK          324619                     30199
# 2    2010    AZ         2470950                     66596
# 3    2010    AR         1189709                     60584
# 4    2010    CA        15097170                    346580
# ..    ...   ...             ...                       ...
# 505  2019    VA         4044679                     81541
# 506  2019    WA         3481251                     88373
# 507  2019    WV          702086                     26662
# 508  2019    WI         2808648                    118333
# 509  2019    WY          263524                     20543
#
#      Estimate 5 to 9 min  Estimate 10 to 14 min  Estimate 15 to 19 min  \
# 0                 189676                 274724                 330572
# 1                  56593                  58333                  59252
# 2                 243712                 346279                 385741
# 3                 171728                 203607                 207225
# 4                1331209                2102009                2350056
# ..                   ...                    ...                    ...
# 505               318095                 464607                 598280
# 506               307571                 405405                 505883
# 507                80149                 106219                 109586
# 508               365548                 448298                 469881
# 509                64799                  53292                  46264
#
#      Estimate 20 to 24 min  Estimate 25 to 29 min  Estimate 30 to 34 min  ...  \
# 0                   301885                 117283                 264594  ...
# 1                    44082                  16062                  24726  ...
# 2                   376165                 166696                 390622  ...
# 3                   163084                  73975                 136006  ...
# 4                  2255417                 851250                2224075  ...
# ..                     ...                    ...                    ...  ...
# 505                 570837                 284185                 584991  ...
# 506                 474369                 236353                 478642  ...
# 507                  95673                  47189                  78676  ...
# 508                 412629                 198922                 309935  ...
# 509                  22214                   6119                  14962  ...
#
#      Estimate 45 to 59 min  Estimate 60 to 89 min  Estimate 90 or more min  \
# 0                   135707                  76275                    36428
# 1                    12229                   8194                     5665
# 2                   179809                  99719                    39654
# 3                    60070                  35293                    19736
# 4                  1188689                1019773                   452499
# ..                     ...                    ...                      ...
# 505                 389094                 301947                   138005
# 506                 329245                 245917                   125335
# 507                  49325                  41812                    27403
# 508                 161429                  93629                    50010
# 509                  10513                   9821                     7321
#
#      Estiamte Aggregate Travel Time (min)  \
# 0                                45734230
# 1                                 6100595
# 2                                60533900
# 3                                25178550
# 4                               405422285
# ..                                    ...
# 505                             117533485
# 506                             100088410
# 507                              18501245
# 508                              63667210
# 509                               5037795
#
#      Worked in State of Residence Estimate Aggregate (min)  \
# 0                                             42487215
# 1                                              6069265
# 2                                             58957890
# 3                                             23519785
# 4                                            402553330
# ..                                                 ...
# 505                                          100009500
# 506                                           95647125
# 507                                           14119905
# 508                                           59039905
# 509                                            4635125
#
#      Worked in County of Residence Estimate Aggregate (min)  \
# 0                                             25986650
# 1                                              4973180
# 2                                             53765435
# 3                                             14298840
# 4                                            285220410
# ..                                                 ...
# 505                                           37119195
# 506                                           68366485
# 507                                            8387660
# 508                                           34763360
# 509                                            3821070
#
#      Worked Outside County of Residence Estimate Aggregate (min)  \
# 0                                             16500565
# 1                                              1096085
# 2                                              5192455
# 3                                              9220950
# 4                                            117332920
# ..                                                 ...
# 505                                           62890300
# 506                                           27280640
# 507                                            5732245
# 508                                           24276545
# 509                                             814055
#
#      Worked Outside State of Residence Estimate Aggregate (min)  \
# 0                                              3247015
# 1                                                31325
# 2                                              1576015
# 3                                              1658765
# 4                                              2868955
# ..                                                 ...
# 505                                           17523985
# 506                                            4441285
# 507                                            4381340
# 508                                            4627305
# 509                                             402670
#
#     Yearly Average Index (NSA)  Yearly Average Index (SA)
# 0                     180.7875                   180.1300
# 1                     219.9000                   218.8725
# 2                     183.1500                   182.7550
# 3                     178.3125                   178.0825
# 4                     164.7850                   163.9675
# ..                         ...                        ...
# 505                   265.6275                   264.4825
# 506                   381.1050                   378.4850
# 507                   221.2475                   220.6050
# 508                   271.7300                   270.4950
# 509                   356.6025                   353.7250
#
# [510 rows x 22 columns]

# %% [markdown]
# # HPI Summary

# %%
df_2010_2019 = travel_hpi.loc[(travel_hpi['Year'] == '2010') | (travel_hpi['Year'] == '2019')]
state_groupby = df_2010_2019.groupby('State')
# Calculating change in HPI (both NSA and SA) over time (2010 to 2019) for each state
states = df_2010_2019['State'].unique()

change_nsa = state_groupby['Yearly Average Index (NSA)'].diff().dropna()
change_sa = state_groupby['Yearly Average Index (SA)'].diff().dropna()
pct_change_nsa = state_groupby['Yearly Average Index (NSA)'].pct_change().dropna()
pct_change_sa = state_groupby['Yearly Average Index (SA)'].pct_change().dropna()
hpi_change = pd.DataFrame({'State': states, 'Change in NSA Index': change_nsa, 'Percent Change in NSA Index': pct_change_nsa, \
    'Change in SA Index': change_sa, 'Percent Change in SA Index': pct_change_sa})
hpi_change = hpi_change.reset_index(drop=True)
hpi_change.style.format({'Percent Change in NSA Index': '{:,.2f}%'.format, 'Percent Change in SA Index': '{:,.2f}%'.format})
# Out:
# <style  type="text/css" >
# </style><table id="T_c33da_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >State</th>        <th class="col_heading level0 col1" >Change in NSA Index</th>        <th class="col_heading level0 col2" >Percent Change in NSA Index</th>        <th class="col_heading level0 col3" >Change in SA Index</th>        <th class="col_heading level0 col4" >Percent Change in SA Index</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c33da_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_c33da_row0_col0" class="data row0 col0" >AL</td>
#                         <td id="T_c33da_row0_col1" class="data row0 col1" >48.627500</td>
#                         <td id="T_c33da_row0_col2" class="data row0 col2" >0.27%</td>
#                         <td id="T_c33da_row0_col3" class="data row0 col3" >48.467500</td>
#                         <td id="T_c33da_row0_col4" class="data row0 col4" >0.27%</td>
#             </tr>
#             <tr>
#                         <th id="T_c33da_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_c33da_row1_col0" class="data row1 col0" >AK</td>
#                         <td id="T_c33da_row1_col1" class="data row1 col1" >45.180000</td>
#                         <td id="T_c33da_row1_col2" class="data row1 col2" >0.21%</td>
#                         <td id="T_c33da_row1_col3" class="data row1 col3" >45.012500</td>
#                         <td id="T_c33da_row1_col4" class="data row1 col4" >0.21%</td>
#             </tr>
#             <tr>
#                         <th id="T_c33da_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_c33da_row2_col0" class="data row2 col0" >AZ</td>
#                         <td id="T_c33da_row2_col1" class="data row2 col1" >151.690000</td>
#                         <td id="T_c33da_row2_col2" class="data row2 col2" >0.83%</td>
#                         <td id="T_c33da_row2_col3" class="data row2 col3" >151.385000</td>
#                         <td id="T_c33da_row2_col4" class="data row2 col4" >0.83%</td>
#             </tr>
#             <tr>
#                         <th id="T_c33da_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_c33da_row3_col0" class="data row3 col0" >AR</td>
#                         <td id="T_c33da_row3_col1" class="data row3 col1" >46.727500</td>
#                         <td id="T_c33da_row3_col2" class="data row3 col2" >0.26%</td>
#                         <td id="T_c33da_row3_col3" class="data row3 col3" >46.552500</td>
#                         <td id="T_c33da_row3_col4" class="data row3 col4" >0.26%</td>
#             </tr>
#             <tr>
#                         <th id="T_c33da_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_c33da_row4_col0" class="data row4 col0" >CA</td>
#                         <td id="T_c33da_row4_col1" class="data row4 col1" >124.192500</td>
#                         <td id="T_c33da_row4_col2" class="data row4 col2" >0.75%</td>
#                         <td id="T_c33da_row4_col3" class="data row4 col3" >123.555000</td>
#                         <td id="T_c33da_row4_col4" class="data row4 col4" >0.75%</td>
#             </tr>
#             <tr>
#                         <th id="T_c33da_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_c33da_row5_col0" class="data row5 col0" >CO</td>
#                         <td id="T_c33da_row5_col1" class="data row5 col1" >216.760000</td>
#                         <td id="T_c33da_row5_col2" class="data row5 col2" >0.84%</td>
#                         <td id="T_c33da_row5_col3" class="data row5 col3" >215.672500</td>
#                         <td id="T_c33da_row5_col4" class="data row5 col4" >0.84%</td>
#             </tr>
#             <tr>
#                         <th id="T_c33da_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_c33da_row6_col0" class="data row6 col0" >CT</td>
#                         <td id="T_c33da_row6_col1" class="data row6 col1" >7.127500</td>
#                         <td id="T_c33da_row6_col2" class="data row6 col2" >0.04%</td>
#                         <td id="T_c33da_row6_col3" class="data row6 col3" >7.125000</td>
#                         <td id="T_c33da_row6_col4" class="data row6 col4" >0.04%</td>
#             </tr>
#             <tr>
#                         <th id="T_c33da_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_c33da_row7_col0" class="data row7 col0" >DE</td>
#                         <td id="T_c33da_row7_col1" class="data row7 col1" >24.967500</td>
#                         <td id="T_c33da_row7_col2" class="data row7 col2" >0.13%</td>
#                         <td id="T_c33da_row7_col3" class="data row7 col3" >25.005000</td>
#                         <td id="T_c33da_row7_col4" class="data row7 col4" >0.13%</td>
#             </tr>
#             <tr>
#                         <th id="T_c33da_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_c33da_row8_col0" class="data row8 col0" >DC</td>
#                         <td id="T_c33da_row8_col1" class="data row8 col1" >232.167500</td>
#                         <td id="T_c33da_row8_col2" class="data row8 col2" >0.73%</td>
#                         <td id="T_c33da_row8_col3" class="data row8 col3" >230.285000</td>
#                         <td id="T_c33da_row8_col4" class="data row8 col4" >0.73%</td>
#             </tr>
#             <tr>
#                         <th id="T_c33da_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_c33da_row9_col0" class="data row9 col0" >FL</td>
#                         <td id="T_c33da_row9_col1" class="data row9 col1" >139.995000</td>
#                         <td id="T_c33da_row9_col2" class="data row9 col2" >0.79%</td>
#                         <td id="T_c33da_row9_col3" class="data row9 col3" >139.717500</td>
#                         <td id="T_c33da_row9_col4" class="data row9 col4" >0.79%</td>
#             </tr>
#             <tr>
#                         <th id="T_c33da_level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_c33da_row10_col0" class="data row10 col0" >GA</td>
#                         <td id="T_c33da_row10_col1" class="data row10 col1" >89.265000</td>
#                         <td id="T_c33da_row10_col2" class="data row10 col2" >0.56%</td>
#                         <td id="T_c33da_row10_col3" class="data row10 col3" >88.987500</td>
#                         <td id="T_c33da_row10_col4" class="data row10 col4" >0.56%</td>
#             </tr>
#             <tr>
#                         <th id="T_c33da_level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_c33da_row11_col0" class="data row11 col0" >HI</td>
#                         <td id="T_c33da_row11_col1" class="data row11 col1" >84.282500</td>
#                         <td id="T_c33da_row11_col2" class="data row11 col2" >0.48%</td>
#                         <td id="T_c33da_row11_col3" class="data row11 col3" >84.242500</td>
#                         <td id="T_c33da_row11_col4" class="data row11 col4" >0.48%</td>
#             </tr>
#             <tr>
#                         <th id="T_c33da_level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_c33da_row12_col0" class="data row12 col0" >ID</td>
#                         <td id="T_c33da_row12_col1" class="data row12 col1" >161.587500</td>
#                         <td id="T_c33da_row12_col2" class="data row12 col2" >0.80%</td>
#                         <td id="T_c33da_row12_col3" class="data row12 col3" >160.617500</td>
#                         <td id="T_c33da_row12_col4" class="data row12 col4" >0.80%</td>
#             </tr>
#             <tr>
#                         <th id="T_c33da_level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_c

# %% [markdown]
# # Time Traveled to Work Summary

# %%
# Calculating change in travel time over time (2010 to 2019) for each state
change_less5 = state_groupby['Estimate Less than 5 min'].pct_change().dropna()  
change_5to9 = state_groupby['Estimate 5 to 9 min'].pct_change().dropna()
change_10to14 = state_groupby['Estimate 10 to 14 min'].pct_change().dropna()
change_15to19 = state_groupby['Estimate 15 to 19 min'].pct_change().dropna()
change_20to24 = state_groupby['Estimate 20 to 24 min'].pct_change().dropna()
change_10to14 = state_groupby['Estimate 10 to 14 min'].pct_change().dropna()
change_25to29 = state_groupby['Estimate 25 to 29 min'].pct_change().dropna()
change_30to34 = state_groupby['Estimate 30 to 34 min'].pct_change().dropna()
change_35to39 = state_groupby['Estimate 35 to 39 min'].pct_change().dropna()
change_40to44 = state_groupby['Estimate 40 to 44 min'].pct_change().dropna()
change_45to59 = state_groupby['Estimate 45 to 59 min'].pct_change().dropna()
change_60to89 = state_groupby['Estimate 60 to 89 min'].pct_change().dropna()
change_90more = state_groupby['Estimate 90 or more min'].pct_change().dropna()

travel_time_change = pd.DataFrame({'State': states, '% Change <5 min': change_less5, '% Change 5 to 9 min': change_5to9, \
    '% Change 10 to 14 min': change_10to14, '% Change 15 to 19 min': change_15to19, '% Change 20 to 24 min': change_20to24, \
    '% Change 25 to 29 min': change_25to29, '% Change 30 to 34 min': change_30to34, '% Change 35 to 39 min': change_35to39, \
    '% Change 40 to 44 min': change_40to44, '% Change 45 to 59 min': change_45to59, '% Change 60 to 89 min': change_60to89, \
    '% Change > 89 min': change_90more})
travel_time_change = travel_time_change.reset_index(drop=True)
travel_time_change.style.format({'% Change <5 min': '{:,.2f}%'.format, '% Change 5 to 9 min': '{:,.2f}%'.format, \
    '% Change 10 to 14 min': '{:,.2f}%'.format, '% Change 15 to 19 min': '{:,.2f}%'.format, '% Change 20 to 24 min': '{:,.2f}%'.format, \
    '% Change 25 to 29 min': '{:,.2f}%'.format, '% Change 30 to 34 min': '{:,.2f}%'.format, '% Change 35 to 39 min': '{:,.2f}%'.format, \
    '% Change 40 to 44 min': '{:,.2f}%'.format, '% Change 45 to 59 min': '{:,.2f}%'.format, '% Change 60 to 89 min': '{:,.2f}%'.format, \
    '% Change > 89 min': '{:,.2f}%'.format})
# Out:
# <style  type="text/css" >
# </style><table id="T_ffd84_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >State</th>        <th class="col_heading level0 col1" >% Change <5 min</th>        <th class="col_heading level0 col2" >% Change 5 to 9 min</th>        <th class="col_heading level0 col3" >% Change 10 to 14 min</th>        <th class="col_heading level0 col4" >% Change 15 to 19 min</th>        <th class="col_heading level0 col5" >% Change 20 to 24 min</th>        <th class="col_heading level0 col6" >% Change 25 to 29 min</th>        <th class="col_heading level0 col7" >% Change 30 to 34 min</th>        <th class="col_heading level0 col8" >% Change 35 to 39 min</th>        <th class="col_heading level0 col9" >% Change 40 to 44 min</th>        <th class="col_heading level0 col10" >% Change 45 to 59 min</th>        <th class="col_heading level0 col11" >% Change 60 to 89 min</th>        <th class="col_heading level0 col12" >% Change > 89 min</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ffd84_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_ffd84_row0_col0" class="data row0 col0" >AL</td>
#                         <td id="T_ffd84_row0_col1" class="data row0 col1" >-0.09%</td>
#                         <td id="T_ffd84_row0_col2" class="data row0 col2" >0.04%</td>
#                         <td id="T_ffd84_row0_col3" class="data row0 col3" >0.04%</td>
#                         <td id="T_ffd84_row0_col4" class="data row0 col4" >0.06%</td>
#                         <td id="T_ffd84_row0_col5" class="data row0 col5" >0.06%</td>
#                         <td id="T_ffd84_row0_col6" class="data row0 col6" >0.14%</td>
#                         <td id="T_ffd84_row0_col7" class="data row0 col7" >0.06%</td>
#                         <td id="T_ffd84_row0_col8" class="data row0 col8" >0.18%</td>
#                         <td id="T_ffd84_row0_col9" class="data row0 col9" >0.18%</td>
#                         <td id="T_ffd84_row0_col10" class="data row0 col10" >0.23%</td>
#                         <td id="T_ffd84_row0_col11" class="data row0 col11" >0.32%</td>
#                         <td id="T_ffd84_row0_col12" class="data row0 col12" >0.24%</td>
#             </tr>
#             <tr>
#                         <th id="T_ffd84_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_ffd84_row1_col0" class="data row1 col0" >AK</td>
#                         <td id="T_ffd84_row1_col1" class="data row1 col1" >-0.13%</td>
#                         <td id="T_ffd84_row1_col2" class="data row1 col2" >0.07%</td>
#                         <td id="T_ffd84_row1_col3" class="data row1 col3" >0.05%</td>
#                         <td id="T_ffd84_row1_col4" class="data row1 col4" >0.06%</td>
#                         <td id="T_ffd84_row1_col5" class="data row1 col5" >0.01%</td>
#                         <td id="T_ffd84_row1_col6" class="data row1 col6" >0.05%</td>
#                         <td id="T_ffd84_row1_col7" class="data row1 col7" >0.09%</td>
#                         <td id="T_ffd84_row1_col8" class="data row1 col8" >-0.41%</td>
#                         <td id="T_ffd84_row1_col9" class="data row1 col9" >-0.14%</td>
#                         <td id="T_ffd84_row1_col10" class="data row1 col10" >-0.04%</td>
#                         <td id="T_ffd84_row1_col11" class="data row1 col11" >0.12%</td>
#                         <td id="T_ffd84_row1_col12" class="data row1 col12" >0.41%</td>
#             </tr>
#             <tr>
#                         <th id="T_ffd84_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_ffd84_row2_col0" class="data row2 col0" >AZ</td>
#                         <td id="T_ffd84_row2_col1" class="data row2 col1" >0.09%</td>
#                         <td id="T_ffd84_row2_col2" class="data row2 col2" >0.16%</td>
#                         <td id="T_ffd84_row2_col3" class="data row2 col3" >0.08%</td>
#                         <td id="T_ffd84_row2_col4" class="data row2 col4" >0.15%</td>
#                         <td id="T_ffd84_row2_col5" class="data row2 col5" >0.20%</td>
#                         <td id="T_ffd84_row2_col6" class="data row2 col6" >0.39%</td>
#                         <td id="T_ffd84_row2_col7" class="data row2 col7" >0.14%</td>
#                         <td id="T_ffd84_row2_col8" class="data row2 col8" >0.41%</td>
#                         <td id="T_ffd84_row2_col9" class="data row2 col9" >0.21%</td>
#                         <td id="T_ffd84_row2_col10" class="data row2 col10" >0.43%</td>
#                         <td id="T_ffd84_row2_col11" class="data row2 col11" >0.75%</td>
#                         <td id="T_ffd84_row2_col12" class="data row2 col12" >0.75%</td>
#             </tr>
#             <tr>
#                         <th id="T_ffd84_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_ffd84_row3_col0" class="data row3 col0" >AR</td>
#                         <td id="T_ffd84_row3_col1" class="data row3 col1" >-0.01%</td>
#                         <td id="T_ffd84_row3_col2" class="data row3 col2" >-0.00%</td>
#                         <td id="T_ffd84_row3_col3" class="data row3 col3" >0.10%</td>
#                         <td id="T_ffd84_row3_col4" class="data row3 col4" >0.05%</td>
#                         <td id="T_ffd84_row3_col5" class="data row3 col5" >0.04%</td>
#                         <td id="T_ffd84_row3_col6" class="data row3 col6" >-0.03%</td>
#                         <td id="T_ffd84_row3_col7" class="data row3 col7" >0.08%</td>
#                         <td id="T_ffd84_row3_col8" class="data row3 col8" >0.15%</td>
#                         <td id="T_ffd84_row3_col9" class="data row3 col9" >0.19%</td>
#                         <td id="T_ffd84_row3_col10" class="data row3 col10" >0.21%</td>
#                         <td id="T_ffd84_row3_col11" class="data row3 col11" >0.19%</td>
#                         <td id="T_ffd84_row3_col12" class="data row3 col12" >0.18%</td>
#             </tr>
#             <tr>
#                         <th id="T_ffd84_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_ffd84_row4_col0" class="data row4 col0" >CA</td>
#                         <td id="T_ffd84_row4_col1" class="data row4 col1" >-0.13%</td>
#                         <td id="T_ffd84_row4_col2" class="data row4 col2" >-0.07%</td>
#                         <td id="T_ffd84_row4_col3" class="data row4 col3" >-0.02%</td>
#                         <td id="T_ffd84_row4_col4" class="data row4 col4" >0.06%</td>
#                         <td id="T_ffd84_row4_col5" class="data row4 col5" >0.08%</td>
#                         <td id="T_ffd84_row4_col6" class="data row4 col6" >0.27%</td>
#                         <td id="T_ffd84_row4_col7" class="data row4 col7" >0.18%</td>
#                         <td id="T_ffd84_row4_col8" class="data row4 col8" >0.34%</td>
#                         <td id="T_ffd84_row4_col9" class="data row4 col9" >0.35%</td>
#                         <td id="T_ffd84_row4_col10" class="data row4 col10" >0.37%</td>
#                         <td id="T_ffd84_row4_col11" class="data row4 col11" >0.55%</td>
#                         <td id="T_ffd84_row4_col12" class="data row4 col12" >0.79%</td>
#             </tr>
#             <tr>
#                         <th id="T_ffd84_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_ffd84_row5_col0" class="data row5 col0" >CO</td>
#                         <td id="T_ffd84_row5_col1" class="data row5 col1" >-0.20%</td>
#                         <td id="T_ffd84_row5_col2" class="data row5 col2" >-0.03%</td>
#                         <td id="T_ffd84_row5_col3" class="data row5 col3" >0.07%</td>
#                         <td id="T_ffd84_row5_col4" class="data row5 col4" >0.16%</td>
#                         <td id="T_ffd84_row5_col5" class="data row5 col5" >0.21%</td>
#                         <td id="T_ffd84_row5_col6" class="data row5 col6" >0.23%</
